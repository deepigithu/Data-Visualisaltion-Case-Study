# %%
import numpy as np
import pandas as pd 
import datetime as dt 
import matplotlib.pyplot as  plt  
import seaborn as sns

# %%
sales_data=pd.read_csv(r'C:\Users\Deepika\Downloads\PYTHON\SalesData.csv')

# %%
sales_data
# Out:
#       AccountId  AccountName   Region       Division        City State  Tier  \
# 0          1116     Account1     West    DIAMONDBACK   PHOENIX W    AZ   Low
# 1          1116     Account1     West    DIAMONDBACK   PHOENIX W    AZ   Low
# 2          2391     Account2     East      MINUTEMEN    HARTFORD    CT   Med
# 3          2391     Account2     East      MINUTEMEN    HARTFORD    CT   Med
# 4          2397     Account3     East      MINUTEMEN   WORCESTER    MA   Med
# ...         ...          ...      ...            ...         ...   ...   ...
# 3704       7576  Account2736     East         EMPIRE    SYRACUSE    NY   Out
# 3705       4969  Account2740  Central  SOUTHERN STAR  MONTGOMERY    AL   Med
# 3706       2850  Account2746     East        SYNERGY   ASHEVILLE    NC  High
# 3707    1102265  Account2748     West    DIAMONDBACK  SCOTTSDALE    AZ   Out
# 3708      47282  Account2750     West       CHARGERS    SAN JOSE    CA   Low
#
# ...

# %%
#1
region_sales=sales_data.groupby(by='Region')[['Sales2015','Sales2016']].sum()

# %%
region_sales.plot(kind='bar',title="Sales by Region in 2015 and 2016")
plt.show()

# %%
#2
region_sales2016=sales_data.groupby(by='Region')['Sales2016'].sum()

# %%
plt.pie(region_sales2016,autopct="%1.0f%%",labels=['Central','East','West'],shadow=True,colors=['r','g','b'])
plt.title("Contributing Factors  to the Sales for each Region in 2016")
plt.show()

# %%
#3
sales_by_reti=sales_data.groupby(by=['Region','Tier'])[['Sales2015','Sales2016']].sum()

# %%
sales_by_reti.plot(kind='bar',figsize=[10,5],title='Total Sales of 2015 and 2016 with respect to Region and Tier')
plt.show()

# %%
#4
EastRegion=sales_data.loc[sales_data.Region=='East']
EastRegion
# Out:
#       AccountId  AccountName Region   Division              City State  Tier  \
# 2          2391     Account2   East  MINUTEMEN          HARTFORD    CT   Med
# 3          2391     Account2   East  MINUTEMEN          HARTFORD    CT   Med
# 4          2397     Account3   East  MINUTEMEN         WORCESTER    MA   Med
# 5          2400     Account4   East  MINUTEMEN          PORTLAND    ME  High
# 6          2400     Account4   East  MINUTEMEN          PORTLAND    ME  High
# ...         ...          ...    ...        ...               ...   ...   ...
# 3682       7239  Account2716   East  MINUTEMEN          BOSTON N    MA  High
# 3695       7920  Account2725   East      ORION  SAINT PETERSBURG    FL   Med
# 3700    1174604  Account2733   East  BIG APPLE          BROOKLYN    NY   Out
# 3704       7576  Account2736   East     EMPIRE          SYRACUSE    NY   Out
# 3706       2850  Account2746   East    SYNERGY         ASHEVILLE    NC  High
#
# ...

# %%
east_sales=EastRegion.groupby(by=['Region','State'])[['Sales2015','Sales2016']].sum()

# %%
east_sales.plot(kind='bar',figsize=[10,5],title='Comparison of Total Sales in 2015 and 2016 in East Region by State')
plt.show()

# %% [markdown]
# # In East Region, NY registered a decline Sales in 2016

# %%
#5
hightier=sales_data.loc[sales_data.Tier=='High']
hightier
# Out:
#       AccountId  AccountName   Region   Division         City State  Tier  \
# 5          2400     Account4     East  MINUTEMEN     PORTLAND    ME  High
# 6          2400     Account4     East  MINUTEMEN     PORTLAND    ME  High
# 9          2408     Account7     East  BIG APPLE  JERSEY CITY    NJ  High
# 10         2408     Account7     East  BIG APPLE  JERSEY CITY    NJ  High
# 17         2426    Account13     East  BIG APPLE     PATERSON    NJ  High
# ...         ...          ...      ...        ...          ...   ...   ...
# 3699       3048  Account2731  Central    RACEWAY    OWENSBORO    KY  High
# 3701       7076  Account2735  Central   WRANGLER    HOUSTON S    TX  High
# 3702       7076  Account2735  Central   WRANGLER    HOUSTON S    TX  High
# 3703       7076  Account2735  Central   WRANGLER    HOUSTON S    TX  High
# 3706       2850  Account2746     East    SYNERGY    ASHEVILLE    NC  High
#
#      Month  Sales2015  Sales2016  Units2015  Units2016  TargetAchevied2015  \
# ...

# %%
hightier=hightier.groupby(by='Division')[['Units2015','Units2016']].sum()
hightier.plot(kind='bar',figsize=[20,10],title='Comparison of Units sold in 2015 and 2016 in High Tier by Division')
plt.show()

# %% [markdown]
# # We observe that in High Tier, none of Division is declining in number of units sold in 2016 compared to 2015

# %%
#6
Qtr=[ ]
for x in sales_data.Month:
    if x in ['Jan','Feb','Mar']:
        Qtr.append('Q1')
    elif x in ['Apr','May','Jun']:
        Qtr.append('Q2')
    elif x in ['Jul','Aug','Sep']:
        Qtr.append('Q3')
    else:
        Qtr.append('Q4')

# %%
Qtr
# Out:
# ['Q3',
#  'Q4',
#  'Q2',
#  'Q1',
#  'Q3',
#  'Q3',
#  'Q1',
#  'Q1',
#  'Q1',
#  'Q3',
#  'Q1',
#  'Q1',
#  'Q3',
#  'Q1',
#  'Q3',
#  'Q4',
#  'Q2',
#  'Q4',
#  'Q2',
#  'Q2',
#  'Q4',
#  'Q2',
#  'Q2',
#  'Q2',
#  'Q4',
#  'Q4',
#  'Q1',
#  'Q2',
#  'Q3',
#  'Q1',
#  'Q1',
#  'Q1',
#  'Q1',
#  'Q2',
#  'Q3',
#  'Q4',
#  'Q2',
#  'Q4',
#  'Q1',
#  'Q4',
#  'Q4',
#  'Q4',
#  'Q1',
#  'Q1',
#  'Q2',
#  'Q2',
#  'Q2',
#  'Q1',
#  'Q4',
#  'Q3',
#  'Q4',
#  'Q1',
#  'Q1',
#  'Q3',
#  'Q2',
#  'Q3',
#  'Q1',
#  'Q2',
#  'Q3',
#  'Q3',
#  'Q4',
#  'Q3',
#  'Q1',
#  'Q4',
#  'Q4',
#  'Q3',
#  'Q1',
#  'Q3',
#  'Q4',
#  'Q1',
#  'Q3',
#  'Q1',
#  'Q3',
#  'Q2',
#  'Q1',
#  'Q3',
#  'Q3',
#  'Q2',
#  'Q4',
#  'Q1',
#  'Q2',
#  'Q4',
#  'Q2',
#  'Q3',
#  'Q2',
#  'Q2',
#  'Q4',
#  'Q3',
#  'Q4',
#  'Q3',
#  'Q2',
#  'Q3',
#  'Q1',
#  'Q3',
#  'Q4',
#  'Q4',
#  'Q2',
#  'Q3',
#  'Q2',
#  'Q4',
#  'Q1',
#  'Q1',
#  'Q4',
#  'Q1',
#  'Q2',
#  'Q1',
#  'Q2',
#  'Q4',
#  'Q4',
#  'Q3',
#  'Q1',
# ...

# %%
sales_data['Qtr']=pd.Series(Qtr)

# %%
sales_data
# Out:
#       AccountId  AccountName   Region       Division        City State  Tier  \
# 0          1116     Account1     West    DIAMONDBACK   PHOENIX W    AZ   Low
# 1          1116     Account1     West    DIAMONDBACK   PHOENIX W    AZ   Low
# 2          2391     Account2     East      MINUTEMEN    HARTFORD    CT   Med
# 3          2391     Account2     East      MINUTEMEN    HARTFORD    CT   Med
# 4          2397     Account3     East      MINUTEMEN   WORCESTER    MA   Med
# ...         ...          ...      ...            ...         ...   ...   ...
# 3704       7576  Account2736     East         EMPIRE    SYRACUSE    NY   Out
# 3705       4969  Account2740  Central  SOUTHERN STAR  MONTGOMERY    AL   Med
# 3706       2850  Account2746     East        SYNERGY   ASHEVILLE    NC  High
# 3707    1102265  Account2748     West    DIAMONDBACK  SCOTTSDALE    AZ   Out
# 3708      47282  Account2750     West       CHARGERS    SAN JOSE    CA   Low
#
# ...

# %%
#7
qtr_sales=sales_data.groupby(by='Qtr')[['Sales2015','Sales2016']].sum()
qtr_sales.plot(kind='bar',title='Qtr wise Sales in 2015 and 2016')
plt.show()

# %%
#8
qtr_tier_sales=sales_data.groupby(by=['Qtr','Tier'])['Sales2016'].sum()
qtr_tier_sales
# Out:
# Qtr  Tier
# Q1   High    3.867719e+06
#      Low     9.488328e+05
#      Med     2.181402e+06
#      Out     0.000000e+00
# Q2   High    4.130953e+06
#      Low     8.905948e+05
#      Med     2.215814e+06
#      Out     0.000000e+00
# Q3   High    4.872559e+06
#      Low     7.951777e+05
#      Med     2.197058e+06
#      Out    -3.248530e+03
# Q4   High    4.740002e+06
#      Low     7.426594e+05
#      Med     2.085207e+06
#      Out     0.000000e+00
# Name: Sales2016, dtype: float64

# %%
#Q1
Q1=qtr_tier_sales.loc['Q1',:]
Q2=qtr_tier_sales.loc['Q2',:]
Q3=qtr_tier_sales.loc['Q3',:]
Q4=qtr_tier_sales.loc['Q4',:]

# %%
#dropping the index 'OUT' because it contains negative value and not allowing to plot the pie chart
Q3=qtr_tier_sales.loc['Q3',:] 
Q3=Q3.drop(index='Out')
Q3
# Out:
# Tier
# High    4.872559e+06
# Low     7.951777e+05
# Med     2.197058e+06
# Name: Sales2016, dtype: float64

# %%
Q1.plot(kind='pie',autopct="%1.0f%%",title='Q1')
plt.show()
Q2.plot(kind='pie',autopct="%1.0f%%",title='Q2')
plt.show()
Q3.plot(kind='pie',autopct="%1.0f%%",title='Q3')
plt.show()

# %%
Q4.plot(kind='pie',autopct="%1.0f%%",title='Q4')
plt.show()
